# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 604

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}data/2.5/weather?q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bara
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | ust-nera
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | kilindoni
# Processing Record 8 of Set 1 | asau
# Processing Record 9 of Set 1 | longyearbyen
# Processing Record 10 of Set 1 | grindavik
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | victoria
# Processing Record 13 of Set 1 | palmer
# Processing Record 14 of Set 1 | bangahan
# Processing Record 15 of Set 1 | ayan
# Processing Record 16 of Set 1 | mirnyy
# Processing Record 17 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | graham
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | palmares do sul
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | tupik
# Processing Record 30 of Set 1 | waipawa
# Processing Record 31 of Set 1 | hasaki
# Processing Record 32 of Set 1 | kampene
# Processing Record 33 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 1 | eyl
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | bagotville
# Processing Record 37 of Set 1 | waxahachie
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | cidreira
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | nizwa
# Processing Record 42 of Set 1 | lata
# Processing Record 43 of Set 1 | cherskiy
# Processing Record 44 of Set 1 | portland
# Processing Record 45 of Set 1 | ashland
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | faya
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | broken hill
# Processing Record 0 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | bakel
# Processing Record 2 of Set 2 | ixtapa
# Processing Record 3 of Set 2 | voh
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | guzelyurt
# Processing Record 6 of Set 2 | saint-pierre
# Processing Record 7 of Set 2 | churapcha
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | wladyslawowo
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 2 | beringovskiy
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | paamiut
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | ancud
# Processing Record 21 of Set 2 | heinola
# Processing Record 22 of Set 2 | upernavik
# Processing Record 23 of Set 2 | hay river
# Processing Record 24 of Set 2 | paracuru
# Processing Record 25 of Set 2 | presidencia roque saenz pena
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | sabha
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 2 | kuytun
# Processing Record 31 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | hobyo
# Processing Record 35 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 2 | alyangula
# Processing Record 37 of Set 2 | san patricio
# Processing Record 38 of Set 2 | teguise
# Processing Record 39 of Set 2 | hirara
# Processing Record 40 of Set 2 | southampton
# Processing Record 41 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 2 | dhidhdhoo
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 2 | alice springs
# Processing Record 47 of Set 2 | camopi
# Processing Record 48 of Set 2 | mataura
# Processing Record 49 of Set 2 | barrow
# Processing Record 0 of Set 3 | bekhtery
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | jieshi
# Processing Record 3 of Set 3 | vaini
# Processing Record 4 of Set 3 | izumo
# Processing Record 5 of Set 3 | port lincoln
# Processing Record 6 of Set 3 | ermelo
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | tasiilaq
# Processing Record 9 of Set 3 | kaspiyskiy
# Processing Record 10 of Set 3 | torbay
# Processing Record 11 of Set 3 | vardo
# Processing Record 12 of Set 3 | brae
# Processing Record 13 of Set 3 | padang
# Processing Record 14 of Set 3 | katsuura
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 3 | khimki
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | lichtenburg
# Processing Record 20 of Set 3 | puerto ayora
# Processing Record 21 of Set 3 | kalmunai
# Processing Record 22 of Set 3 | severo-kurilsk
# Processing Record 23 of Set 3 | luderitz
# Processing Record 24 of Set 3 | sibolga
# Processing Record 25 of Set 3 | manta
# Processing Record 26 of Set 3 | mezen
# Processing Record 27 of Set 3 | cacu
# Processing Record 28 of Set 3 | tura
# Processing Record 29 of Set 3 | suleja
# Processing Record 30 of Set 3 | batagay
# Processing Record 31 of Set 3 | vao
# Processing Record 32 of Set 3 | sept-iles
# Processing Record 33 of Set 3 | inta
# Processing Record 34 of Set 3 | mandalgovi
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | umm kaddadah
# Processing Record 37 of Set 3 | pevek
# Processing Record 38 of Set 3 | faanui
# Processing Record 39 of Set 3 | talnakh
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | sechura
# Processing Record 42 of Set 3 | bandarbeyla
# Processing Record 43 of Set 3 | jutai
# Processing Record 44 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 3 | bluff
# Processing Record 46 of Set 3 | taiobeiras
# Processing Record 47 of Set 3 | lastoursville
# Processing Record 48 of Set 3 | tateyama
# Processing Record 49 of Set 3 | tuktoyaktuk
# Processing Record 0 of Set 4 | kodiak
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | samarai
# Processing Record 3 of Set 4 | myaundzha
# Processing Record 4 of Set 4 | cap malheureux
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | obihiro
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | kempele
# Processing Record 10 of Set 4 | namibe
# Processing Record 11 of Set 4 | klaksvik
# Processing Record 12 of Set 4 | abonnema
# Processing Record 13 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 14 of Set 4 | hofn
# Processing Record 15 of Set 4 | havre-saint-pierre
# Processing Record 16 of Set 4 | cabedelo
# Processing Record 17 of Set 4 | akureyri
# Processing Record 18 of Set 4 | bambous virieux
# Processing Record 19 of Set 4 | quetigny
# Processing Record 20 of Set 4 | isangel
# Processing Record 21 of Set 4 | saskylakh
# Processing Record 22 of Set 4 | kapaa
# Processing Record 23 of Set 4 | seoul
# Processing Record 24 of Set 4 | kamyshla
# Processing Record 25 of Set 4 | richards bay
# Processing Record 26 of Set 4 | ojinaga
# Processing Record 27 of Set 4 | lewistown
# Processing Record 28 of Set 4 | dharchula
# Processing Record 29 of Set 4 | gat
# Processing Record 30 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 4 | ossora
# Processing Record 32 of Set 4 | san cristobal
# Processing Record 33 of Set 4 | la serena
# Processing Record 34 of Set 4 | mount gambier
# Processing Record 35 of Set 4 | megion
# Processing Record 36 of Set 4 | udachnyy
# Processing Record 37 of Set 4 | honningsvag
# Processing Record 38 of Set 4 | banjar
# Processing Record 39 of Set 4 | madras
# Processing Record 40 of Set 4 | mayumba
# Processing Record 41 of Set 4 | rio claro
# Processing Record 42 of Set 4 | suoyarvi
# Processing Record 43 of Set 4 | usinsk
# Processing Record 44 of Set 4 | havoysund
# Processing Record 45 of Set 4 | villa carlos paz
# Processing Record 46 of Set 4 | boa vista
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 4 | jawhar
# Processing Record 0 of Set 5 | norsup
# Processing Record 1 of Set 5 | lavrentiya
# Processing Record 2 of Set 5 | lompoc
# Processing Record 3 of Set 5 | cockburn town
# Processing Record 4 of Set 5 | vila
# Processing Record 5 of Set 5 | teneguiban
# City not found. Skipping...
# Processing Record 6 of Set 5 | ulladulla
# Processing Record 7 of Set 5 | iberia
# Processing Record 8 of Set 5 | ornskoldsvik
# Processing Record 9 of Set 5 | zhigansk
# Processing Record 10 of Set 5 | saint george
# Processing Record 11 of Set 5 | la reforma
# Processing Record 12 of Set 5 | okhotsk
# Processing Record 13 of Set 5 | lincoln
# Processing Record 14 of Set 5 | homer
# Processing Record 15 of Set 5 | abong mbang
# Processing Record 16 of Set 5 | salalah
# Processing Record 17 of Set 5 | kamensk-uralskiy
# Processing Record 18 of Set 5 | la peca
# Processing Record 19 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 5 | spokane
# Processing Record 21 of Set 5 | hermanus
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | qaanaaq
# Processing Record 24 of Set 5 | shelburne
# Processing Record 25 of Set 5 | valleyview
# Processing Record 26 of Set 5 | jiangyou
# Processing Record 27 of Set 5 | alta floresta
# Processing Record 28 of Set 5 | narsaq
# Processing Record 29 of Set 5 | penzberg
# Processing Record 30 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 5 | kavaratti
# Processing Record 32 of Set 5 | khandela
# Processing Record 33 of Set 5 | dunedin
# Processing Record 34 of Set 5 | karratha
# Processing Record 35 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 5 | praia
# Processing Record 37 of Set 5 | wlodawa
# Processing Record 38 of Set 5 | haradok
# Processing Record 39 of Set 5 | constitucion
# Processing Record 40 of Set 5 | ponta delgada
# Processing Record 41 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 5 | abu dhabi
# Processing Record 43 of Set 5 | nemuro
# Processing Record 44 of Set 5 | prince rupert
# Processing Record 45 of Set 5 | sitka
# Processing Record 46 of Set 5 | hanmer springs
# Processing Record 47 of Set 5 | fortuna
# Processing Record 48 of Set 5 | pascagoula
# Processing Record 49 of Set 5 | axim
# Processing Record 0 of Set 6 | villa oliva
# City not found. Skipping...
# Processing Record 1 of Set 6 | dickson
# Processing Record 2 of Set 6 | mbini
# Processing Record 3 of Set 6 | skjervoy
# Processing Record 4 of Set 6 | verkhnevilyuysk
# Processing Record 5 of Set 6 | bethel
# Processing Record 6 of Set 6 | sao filipe
# Processing Record 7 of Set 6 | phan thiet
# Processing Record 8 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 6 | whitehorse
# Processing Record 10 of Set 6 | sao joao da barra
# Processing Record 11 of Set 6 | koscierzyna
# Processing Record 12 of Set 6 | igarka
# Processing Record 13 of Set 6 | krasnyy kholm
# Processing Record 14 of Set 6 | wynyard
# Processing Record 15 of Set 6 | ponta do sol
# Processing Record 16 of Set 6 | bonavista
# Processing Record 17 of Set 6 | qaqortoq
# Processing Record 18 of Set 6 | nouadhibou
# Processing Record 19 of Set 6 | cabo san lucas
# Processing Record 20 of Set 6 | japura
# Processing Record 21 of Set 6 | machilipatnam
# Processing Record 22 of Set 6 | katobu
# Processing Record 23 of Set 6 | tiarei
# Processing Record 24 of Set 6 | itaituba
# Processing Record 25 of Set 6 | te anau
# Processing Record 26 of Set 6 | chifeng
# Processing Record 27 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 28 of Set 6 | banda aceh
# Processing Record 29 of Set 6 | huarmey
# Processing Record 30 of Set 6 | farafangana
# Processing Record 31 of Set 6 | caravelas
# Processing Record 32 of Set 6 | east london
# Processing Record 33 of Set 6 | codrington
# Processing Record 34 of Set 6 | chishtian mandi
# Processing Record 35 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 6 | rio gallegos
# Processing Record 37 of Set 6 | geraldton
# Processing Record 38 of Set 6 | jiwani
# Processing Record 39 of Set 6 | mwene-ditu
# Processing Record 40 of Set 6 | eureka
# Processing Record 41 of Set 6 | bourail
# Processing Record 42 of Set 6 | pangnirtung
# Processing Record 43 of Set 6 | ravar
# Processing Record 44 of Set 6 | bukachacha
# Processing Record 45 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 6 | daru
# Processing Record 47 of Set 6 | siderno
# Processing Record 48 of Set 6 | port hueneme
# Processing Record 49 of Set 6 | katangli
# Processing Record 0 of Set 7 | puksoozero
# Processing Record 1 of Set 7 | maiduguri
# Processing Record 2 of Set 7 | bonfim
# Processing Record 3 of Set 7 | thanh hoa
# Processing Record 4 of Set 7 | tiksi
# Processing Record 5 of Set 7 | uusikaupunki
# Processing Record 6 of Set 7 | chuguyevka
# Processing Record 7 of Set 7 | puerto varas
# Processing Record 8 of Set 7 | wanaka
# Processing Record 9 of Set 7 | nuuk
# Processing Record 10 of Set 7 | pakwach
# City not found. Skipping...
# Processing Record 11 of Set 7 | liverpool
# Processing Record 12 of Set 7 | atbasar
# Processing Record 13 of Set 7 | georgetown
# Processing Record 14 of Set 7 | mount isa
# Processing Record 15 of Set 7 | sansai
# City not found. Skipping...
# Processing Record 16 of Set 7 | crestview
# Processing Record 17 of Set 7 | magadi
# Processing Record 18 of Set 7 | airai
# Processing Record 19 of Set 7 | linqing
# Processing Record 20 of Set 7 | puerto carreno
# Processing Record 21 of Set 7 | berlevag
# Processing Record 22 of Set 7 | yar-sale
# Processing Record 23 of Set 7 | collie
# Processing Record 24 of Set 7 | luoyang
# Processing Record 25 of Set 7 | nsanje
# Processing Record 26 of Set 7 | kenai
# Processing Record 27 of Set 7 | tarumovka
# Processing Record 28 of Set 7 | namatanai
# Processing Record 29 of Set 7 | honiara
# Processing Record 30 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 31 of Set 7 | chamba
# Processing Record 32 of Set 7 | eau claire
# Processing Record 33 of Set 7 | naberera
# Processing Record 34 of Set 7 | teahupoo
# Processing Record 35 of Set 7 | sioux lookout
# Processing Record 36 of Set 7 | quatre cocos
# Processing Record 37 of Set 7 | nome
# Processing Record 38 of Set 7 | opuwo
# Processing Record 39 of Set 7 | yerbogachen
# Processing Record 40 of Set 7 | hirna
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | redmond
# Processing Record 43 of Set 7 | makakilo city
# Processing Record 44 of Set 7 | acapulco
# Processing Record 45 of Set 7 | socorro
# Processing Record 46 of Set 7 | port townsend
# Processing Record 47 of Set 7 | porbandar
# Processing Record 48 of Set 7 | shache
# Processing Record 49 of Set 7 | nouakchott
# Processing Record 0 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 8 | esperance
# Processing Record 2 of Set 8 | tamale
# Processing Record 3 of Set 8 | wagga wagga
# Processing Record 4 of Set 8 | erzin
# Processing Record 5 of Set 8 | cayenne
# Processing Record 6 of Set 8 | nepomuceno
# Processing Record 7 of Set 8 | almeirim
# Processing Record 8 of Set 8 | adrar
# Processing Record 9 of Set 8 | lorengau
# Processing Record 10 of Set 8 | tuatapere
# Processing Record 11 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 8 | margate
# Processing Record 13 of Set 8 | vila velha
# Processing Record 14 of Set 8 | hamilton
# Processing Record 15 of Set 8 | phalombe
# Processing Record 16 of Set 8 | husavik
# Processing Record 17 of Set 8 | kingman
# Processing Record 18 of Set 8 | rajanpur
# Processing Record 19 of Set 8 | korla
# Processing Record 20 of Set 8 | keti bandar
# Processing Record 21 of Set 8 | beloha
# Processing Record 22 of Set 8 | gualaca
# Processing Record 23 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 8 | kokopo
# Processing Record 26 of Set 8 | bowen
# Processing Record 27 of Set 8 | saint-augustin
# Processing Record 28 of Set 8 | araouane
# Processing Record 29 of Set 8 | fukue
# Processing Record 30 of Set 8 | touros
# Processing Record 31 of Set 8 | teknaf
# Processing Record 32 of Set 8 | nanakuli
# Processing Record 33 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 8 | acobamba
# Processing Record 35 of Set 8 | great yarmouth
# Processing Record 36 of Set 8 | balod
# Processing Record 37 of Set 8 | sisimiut
# Processing Record 38 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 8 | bijie
# Processing Record 40 of Set 8 | kununurra
# Processing Record 41 of Set 8 | berezovka
# Processing Record 42 of Set 8 | chodavaram
# Processing Record 43 of Set 8 | lasa
# Processing Record 44 of Set 8 | pizarro
# Processing Record 45 of Set 8 | acarau
# Processing Record 46 of Set 8 | yevsino
# Processing Record 47 of Set 8 | bejucal
# Processing Record 48 of Set 8 | mokhsogollokh
# Processing Record 49 of Set 8 | vila franca do campo
# Processing Record 0 of Set 9 | guaruja
# Processing Record 1 of Set 9 | shingu
# Processing Record 2 of Set 9 | orchard homes
# Processing Record 3 of Set 9 | basco
# Processing Record 4 of Set 9 | baglan
# Processing Record 5 of Set 9 | ust-koksa
# Processing Record 6 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 9 | nosy varika
# Processing Record 8 of Set 9 | lewiston
# Processing Record 9 of Set 9 | auki
# Processing Record 10 of Set 9 | frankfort
# Processing Record 11 of Set 9 | roebourne
# Processing Record 12 of Set 9 | dingzhou
# Processing Record 13 of Set 9 | namwala
# Processing Record 14 of Set 9 | aliwal north
# Processing Record 15 of Set 9 | xiongshi
# City not found. Skipping...
# Processing Record 16 of Set 9 | corinto
# Processing Record 17 of Set 9 | surin
# Processing Record 18 of Set 9 | toamasina
# Processing Record 19 of Set 9 | kemi
# Processing Record 20 of Set 9 | chornobayivka
# Processing Record 21 of Set 9 | marsa matruh
# Processing Record 22 of Set 9 | aksarka
# Processing Record 23 of Set 9 | ahuimanu
# Processing Record 24 of Set 9 | ferme-neuve
# Processing Record 25 of Set 9 | sarny
# Processing Record 26 of Set 9 | teya
# Processing Record 27 of Set 9 | teguldet
# Processing Record 28 of Set 9 | safaqis
# City not found. Skipping...
# Processing Record 29 of Set 9 | westport
# Processing Record 30 of Set 9 | xichang
# Processing Record 31 of Set 9 | evensk
# Processing Record 32 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 33 of Set 9 | kasongo-lunda
# Processing Record 34 of Set 9 | laguna
# Processing Record 35 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 9 | kruisfontein
# Processing Record 37 of Set 9 | berbera
# Processing Record 38 of Set 9 | pingxiang
# Processing Record 39 of Set 9 | qui nhon
# Processing Record 40 of Set 9 | guerrero negro
# Processing Record 41 of Set 9 | natal
# Processing Record 42 of Set 9 | worland
# Processing Record 43 of Set 9 | balykshi
# Processing Record 44 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 9 | rio grande
# Processing Record 46 of Set 9 | achisay
# City not found. Skipping...
# Processing Record 47 of Set 9 | machacamarca
# Processing Record 48 of Set 9 | den helder
# Processing Record 49 of Set 9 | necochea
# Processing Record 0 of Set 10 | port blair
# Processing Record 1 of Set 10 | aleksandrovskoye
# Processing Record 2 of Set 10 | iquique
# Processing Record 3 of Set 10 | taksimo
# Processing Record 4 of Set 10 | khor
# Processing Record 5 of Set 10 | port moresby
# Processing Record 6 of Set 10 | koutiala
# Processing Record 7 of Set 10 | hauterive
# Processing Record 8 of Set 10 | buritis
# Processing Record 9 of Set 10 | pangai
# Processing Record 10 of Set 10 | kibala
# Processing Record 11 of Set 10 | ust-maya
# Processing Record 12 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 13 of Set 10 | gimli
# Processing Record 14 of Set 10 | poum
# Processing Record 15 of Set 10 | oussouye
# Processing Record 16 of Set 10 | itarema
# Processing Record 17 of Set 10 | soc trang
# Processing Record 18 of Set 10 | port hedland
# Processing Record 19 of Set 10 | bayir
# Processing Record 20 of Set 10 | tibagi
# Processing Record 21 of Set 10 | sao felix do xingu
# Processing Record 22 of Set 10 | coquimbo
# Processing Record 23 of Set 10 | henties bay
# Processing Record 24 of Set 10 | marv dasht
# City not found. Skipping...
# Processing Record 25 of Set 10 | leshukonskoye
# Processing Record 26 of Set 10 | chibuto
# Processing Record 27 of Set 10 | tiznit
# Processing Record 28 of Set 10 | kieta
# Processing Record 29 of Set 10 | atherton
# Processing Record 30 of Set 10 | baykit
# Processing Record 31 of Set 10 | cocobeach
# Processing Record 32 of Set 10 | college
# Processing Record 33 of Set 10 | beyneu
# Processing Record 34 of Set 10 | kupang
# Processing Record 35 of Set 10 | noumea
# Processing Record 36 of Set 10 | shahr-e kord
# Processing Record 37 of Set 10 | labytnangi
# Processing Record 38 of Set 10 | lagoa
# Processing Record 39 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 10 | kawalu
# Processing Record 41 of Set 10 | haines junction
# Processing Record 42 of Set 10 | saldus
# Processing Record 43 of Set 10 | leh
# Processing Record 44 of Set 10 | arkhangelos
# City not found. Skipping...
# Processing Record 45 of Set 10 | nauta
# Processing Record 46 of Set 10 | la gaulette
# City not found. Skipping...
# Processing Record 47 of Set 10 | sumkino
# Processing Record 48 of Set 10 | stillwater
# Processing Record 49 of Set 10 | kovur
# Processing Record 0 of Set 11 | inongo
# Processing Record 1 of Set 11 | rabo de peixe
# Processing Record 2 of Set 11 | erdemli
# Processing Record 3 of Set 11 | itoman
# Processing Record 4 of Set 11 | rundu
# Processing Record 5 of Set 11 | oakdale
# Processing Record 6 of Set 11 | emerald
# Processing Record 7 of Set 11 | ludvika
# Processing Record 8 of Set 11 | san felipe
# Processing Record 9 of Set 11 | phnum penh
# City not found. Skipping...
# Processing Record 10 of Set 11 | la paz
# Processing Record 11 of Set 11 | gorontalo
# Processing Record 12 of Set 11 | yumen
# Processing Record 13 of Set 11 | kaitangata
# Processing Record 14 of Set 11 | achinsk
# Processing Record 15 of Set 11 | chota
# Processing Record 16 of Set 11 | stephenville
# Processing Record 17 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 11 | mongoumba
# Processing Record 19 of Set 11 | praia da vitoria
# Processing Record 20 of Set 11 | wajir
# Processing Record 21 of Set 11 | halifax
# Processing Record 22 of Set 11 | camacha
# Processing Record 23 of Set 11 | port-gentil
# Processing Record 24 of Set 11 | the pas
# Processing Record 25 of Set 11 | channel-port aux basques
# Processing Record 26 of Set 11 | robertsport
# Processing Record 27 of Set 11 | komsomolskiy
# Processing Record 28 of Set 11 | windhoek
# Processing Record 29 of Set 11 | nakamura
# Processing Record 30 of Set 11 | rabat
# Processing Record 31 of Set 11 | kavieng
# Processing Record 32 of Set 11 | byron bay
# Processing Record 33 of Set 11 | vila do maio
# Processing Record 34 of Set 11 | vestmannaeyjar
# Processing Record 35 of Set 11 | launceston
# Processing Record 36 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 11 | surman
# Processing Record 38 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 39 of Set 11 | srednekolymsk
# Processing Record 40 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 41 of Set 11 | avera
# Processing Record 42 of Set 11 | ejby
# Processing Record 43 of Set 11 | baker city
# Processing Record 44 of Set 11 | juneau
# Processing Record 45 of Set 11 | neijiang
# Processing Record 46 of Set 11 | thunder bay
# Processing Record 47 of Set 11 | pochutla
# Processing Record 48 of Set 11 | roma
# Processing Record 49 of Set 11 | tecoanapa
# Processing Record 0 of Set 12 | bilibino
# Processing Record 1 of Set 12 | umba
# Processing Record 2 of Set 12 | dukat
# Processing Record 3 of Set 12 | bongaree
# Processing Record 4 of Set 12 | tazovskiy
# Processing Record 5 of Set 12 | phangnga
# Processing Record 6 of Set 12 | coihaique
# Processing Record 7 of Set 12 | manbij
# Processing Record 8 of Set 12 | bilma
# Processing Record 9 of Set 12 | kahului
# Processing Record 10 of Set 12 | severomuysk
# Processing Record 11 of Set 12 | dwarka
# Processing Record 12 of Set 12 | cuyutlan
# City not found. Skipping...
# Processing Record 13 of Set 12 | ayagoz
# Processing Record 14 of Set 12 | bud
# Processing Record 15 of Set 12 | ingham
# Processing Record 16 of Set 12 | sur
# Processing Record 17 of Set 12 | salinopolis
# Processing Record 18 of Set 12 | manicore
# Processing Record 19 of Set 12 | novo horizonte
# Processing Record 20 of Set 12 | praya
# Processing Record 21 of Set 12 | simeykyne
# Processing Record 22 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 23 of Set 12 | ahipara
# Processing Record 24 of Set 12 | traralgon
# Processing Record 25 of Set 12 | alofi
# Processing Record 26 of Set 12 | christchurch
# Processing Record 27 of Set 12 | tabalosos
# Processing Record 28 of Set 12 | tevriz
# Processing Record 29 of Set 12 | road town
# Processing Record 30 of Set 12 | mbeya
# Processing Record 31 of Set 12 | forbes
# Processing Record 32 of Set 12 | lazaro cardenas
# Processing Record 33 of Set 12 | kapuskasing
# Processing Record 34 of Set 12 | sumbe
# Processing Record 35 of Set 12 | taoudenni
# Processing Record 36 of Set 12 | palora
# Processing Record 37 of Set 12 | outjo
# Processing Record 38 of Set 12 | urengoy
# Processing Record 39 of Set 12 | sorland
# Processing Record 40 of Set 12 | beian
# Processing Record 41 of Set 12 | taga
# Processing Record 42 of Set 12 | dargaville
# Processing Record 43 of Set 12 | egvekinot
# Processing Record 44 of Set 12 | burhar
# Processing Record 45 of Set 12 | bivolari
# Processing Record 46 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 12 | mecca
# Processing Record 48 of Set 12 | camana
# Processing Record 49 of Set 12 | haveli
# Processing Record 0 of Set 13 | manzanillo
# Processing Record 1 of Set 13 | orange
# Processing Record 2 of Set 13 | santa rosa
# Processing Record 3 of Set 13 | ensley
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame

city_data_df = pd.DataFrame.from_records(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          547
# Lat           547
# Lng           547
# Max Temp      547
# Humidity      547
# Cloudiness    547
# Wind Speed    547
# Country       547
# Date          547
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            bara  10.3744   10.7288    296.32        22           0
# 1         ushuaia -54.8000  -68.3000    281.96        66          40
# 2        ust-nera  64.5667  143.2000    232.50        99          83
# 3  port elizabeth -33.9180   25.5701    294.32        88           0
# 4          albany  42.6001  -73.9662    280.90        44         100
#
#    Wind Speed Country        Date
# 0        4.41      NG  1676839014
# 1        8.23      AR  1676838939
# 2        1.15      RU  1676839015
# 3        2.06      ZA  1676839016
# 4        0.89      US  1676838482

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  bara  10.3744   10.7288    296.32        22           0
# 1               ushuaia -54.8000  -68.3000    281.96        66          40
# 2              ust-nera  64.5667  143.2000    232.50        99          83
# 3        port elizabeth -33.9180   25.5701    294.32        88           0
# 4                albany  42.6001  -73.9662    280.90        44         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.41      NG  1676839014
# 1              8.23      AR  1676838939
# 2              1.15      RU  1676839015
# 3              2.06      ZA  1676839016
# 4              0.89      US  1676838482

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)


# Incorporate the other graph properties
plt.title("Latitude vs Temperture (K)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title("Latitude vs Humidity(%)")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title("Latitude vs Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title("Latitude vs Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Perform a linear regression on
x_axis = city_data_df['Lat']
y_axis = city_data_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)

# Get regression values
regress_values = x_axis * slope + intercept
print(regress_values)
# Out:
# City_ID
# 0      3.752845
# 1      3.735327
# 2      3.767412
# 3      3.740940
# 4      3.761507
#          ...
# 542    3.758242
# 543    3.755525
# 544    3.759115
# 545    3.753904
# 546    3.758260
# Name: Lat, Length: 547, dtype: float64

# %%
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = 0.0x +3.75

# %%
# Define a function to create Linear Regression plots
# Def regression_line(x, y):
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

plt.xlabel(x_axis)
plt.ylabel(y_axis)
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

plt.show()
# Out:
# /Users/jacqlyn/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/8f/3tjfn9hd47v4kwn413mdpmk00000gn/T/ipykernel_79120/1739500603.py in <module>
#       4 plt.plot(x_values,regress_values,"r-")
#       5
# ----> 6 plt.xlabel(x_axis)
#       7 plt.ylabel(y_axis)
#       8 plt.annotate(line_eq,(20,15),fontsize=15,color="red")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/pyplot.py in xlabel(xlabel, fontdict, labelpad, **kwargs)
#    3068 def xlabel(xlabel, fontdict=None, labelpad=None, **kwargs):
#    3069     return gca().set_xlabel(
# -> 3070         xlabel, fontdict=fontdict, labelpad=labelpad, **kwargs)
#    3071
#    3072
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/axes/_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, **kwargs)
#     245         if labelpad is not None:
#     246             self.xaxis.labelpad = labelpad
# --> 247         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     248
#     249     def get_ylabel(self):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/axis.py in set_label_text(self, label, fontdict, **kwargs)
#    1594         """
#    1595         self.isDefault_label = False
# -> 1596         self.label.set_text(label)
#    1597         if fontdict is not None:
#    1598             self.label.update(fontdict)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/text.py in set_text(self, s)
#    1148         if s is None:
#    1149             s = ''
# -> 1150         if s != self._text:
#    1151             self._text = str(s)
#    1152             self.stale = True
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]


# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            bara  10.3744   10.7288    296.32        22           0
# 2        ust-nera  64.5667  143.2000    232.50        99          83
# 4          albany  42.6001  -73.9662    280.90        44         100
# 5        thompson  55.7435  -97.8558    246.24        58           0
# 7            asau  46.4333   26.4000    279.66        95          82
#
#          Wind Speed Country        Date
# City_ID
# 0              4.41      NG  1676839014
# 2              1.15      RU  1676839015
# 4              0.89      US  1676838482
# 5              2.57      CA  1676839016
# 7              1.12      RO  1676839017

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1               ushuaia -54.8000  -68.3000    281.96        66          40
# 3        port elizabeth -33.9180   25.5701    294.32        88           0
# 6             kilindoni  -7.9139   39.6668    300.47        77          26
# 10             saldanha -33.0117   17.9442    293.18        81          61
# 17               avarua -21.2078 -159.7750    302.18        74          30
#
#          Wind Speed Country        Date
# City_ID
# 1              8.23      AR  1676838939
# 3              2.06      ZA  1676839016
# 6              5.73      TZ  1676839017
# 10             5.03      ZA  1676839019
# 17             5.14      CK  1676839023

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])

# create a scatter plot of the Max Temp vs. Latitude data
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])

# add the linear regression line to the plot
x = northern_hemi_df['Lat']
y = slope * x + intercept
plt.plot(x, y, color='red')

# set the plot title and labels
plt.title('Max Temp vs. Latitude (Northern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# display the plot
plt.show()

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

slope, intercept, r_value, p_value, std_err = linregress(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])

# create a scatter plot of the Max Temp vs. Latitude data
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])

# add the linear regression line to the plot
x = southern_hemi_df['Lat']
y = slope * x + intercept
plt.plot(x, y, color='red')

# set the plot title and labels
plt.title('Max Temp vs. Latitude (Northern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# display the plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** Based on the two scatter plots and regression line, the closer to 0 or equator a city is, the higher the max tempeture is.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])

# create a scatter plot of the Max Temp vs. Latitude data
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])

# add the linear regression line to the plot
x = northern_hemi_df['Lat']
y = slope * x + intercept
plt.plot(x, y, color='red')

# set the plot title and labels
plt.title('Humidity vs. Latitude (Northern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# display the plot
plt.show()

# %%
# Southern Hemisphere

slope, intercept, r_value, p_value, std_err = linregress(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])

# create a scatter plot of the Max Temp vs. Latitude data
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])

# add the linear regression line to the plot
x = southern_hemi_df['Lat']
y = slope * x + intercept
plt.plot(x, y, color='red')

# set the plot title and labels
plt.title('Humidity vs. Latitude (Northern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# display the plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])

# create a scatter plot of the Max Temp vs. Latitude data
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])

# add the linear regression line to the plot
x = northern_hemi_df['Lat']
y = slope * x + intercept
plt.plot(x, y, color='red')

# set the plot title and labels
plt.title('Cloudiness vs. Latitude (Northern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# display the plot
plt.show()

# %%
# Southern Hemisphere
slope, intercept, r_value, p_value, std_err = linregress(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])

# create a scatter plot of the Max Temp vs. Latitude data
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])

# add the linear regression line to the plot
x = southern_hemi_df['Lat']
y = slope * x + intercept
plt.plot(x, y, color='red')

# set the plot title and labels
plt.title('Cloudiness vs. Latitude (Northern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# display the plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])

# create a scatter plot of the Max Temp vs. Latitude data
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])

# add the linear regression line to the plot
x = northern_hemi_df['Lat']
y = slope * x + intercept
plt.plot(x, y, color='red')

# set the plot title and labels
plt.title('Wind Speed vs. Latitude (Northern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# display the plot
plt.show()

# %%
# Southern Hemisphere
slope, intercept, r_value, p_value, std_err = linregress(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])

# create a scatter plot of the Max Temp vs. Latitude data
plt.scatter(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])

# add the linear regression line to the plot
x = southern_hemi_df['Lat']
y = slope * x + intercept
plt.plot(x, y, color='red')

# set the plot title and labels
plt.title('Wind Speed vs. Latitude (Northern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# display the plot
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
